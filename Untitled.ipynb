# %%
import pandas as pd

# %%
df = pd.read_csv('mission_launches.csv')

# %%
df['date'] = pd.to_datetime(df.Date, format='mixed')

# %%
df.loc[106]
# Out:
# Unnamed: 0.1                                                    106
# Unnamed: 0                                                      106
# Organisation                                                    ISA
# Location          Imam Khomeini Spaceport, Semnan Space Center, ...
# Date                                               Thu Aug 29, 2019
# Detail                                          Safir-1B+ | Nahid-1
# Rocket_Status                                          StatusActive
# Price                                                           NaN
# Mission_Status                                    Prelaunch Failure
# date                                            2019-08-29 00:00:00
# Name: 106, dtype: object

# %%
df.dtypes
# Out:
# Unnamed: 0.1       int64
# Unnamed: 0         int64
# Organisation      object
# Location          object
# Date              object
# Detail            object
# Rocket_Status     object
# Price             object
# Mission_Status    object
# date              object
# dtype: object

# %%
type(df.loc[106]['date'])
# Out:
# datetime.datetime

# %%
df['dAte'] = df.date.dt.strftime("%Y-%m-%d")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df['dAte'] = df.date.dt.strftime("%Y-%m-%d")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
# ...

# %%
df
# Out:
#       Unnamed: 0.1  Unnamed: 0 Organisation  \
# 0                0           0       SpaceX
# 1                1           1         CASC
# 2                2           2       SpaceX
# 3                3           3    Roscosmos
# 4                4           4          ULA
# ...            ...         ...          ...
# 4319          4319        4319      US Navy
# 4320          4320        4320         AMBA
# 4321          4321        4321      US Navy
# 4322          4322        4322    RVSN USSR
# 4323          4323        4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# ...

# %%
df['fok'] = pd.to_datetime(df.Date,'infer_datetime_format=True')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df['fok'] = pd.to_datetime(df.Date,'infer_datetime_format=True')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:1050, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1048         result = arg.map(cache_array)
#    1049     else:
# -> 1050         values = convert_listlike(arg._values, format)
#    1051         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1052 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:453, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...

# %%
df['fok'] = df['Date'].apply(lambda x: pd.to_datetime(x).strftime('%Y-%m-%d'))

# %%
df.loc[106]
# Out:
# Unnamed: 0.1                                                    106
# Unnamed: 0                                                      106
# Organisation                                                    ISA
# Location          Imam Khomeini Spaceport, Semnan Space Center, ...
# Date                                               Thu Aug 29, 2019
# Detail                                          Safir-1B+ | Nahid-1
# Rocket_Status                                          StatusActive
# Price                                                           NaN
# Mission_Status                                    Prelaunch Failure
# date                                            2019-08-29 00:00:00
# fok                                                      2019-08-29
# Name: 106, dtype: object

# %%
df.dtypes
# Out:
# Unnamed: 0.1       int64
# Unnamed: 0         int64
# Organisation      object
# Location          object
# Date              object
# Detail            object
# Rocket_Status     object
# Price             object
# Mission_Status    object
# date              object
# fok               object
# dtype: object

# %%
df['fuck'] = pd.to_datetime(df.fok)

# %%
df.dtypes
# Out:
# Unnamed: 0.1               int64
# Unnamed: 0                 int64
# Organisation              object
# Location                  object
# Date              datetime64[ns]
# Detail                    object
# Rocket_Status             object
# Price                     object
# Mission_Status            object
# date                      object
# fok                       object
# fuck              datetime64[ns]
# dtype: object

# %%
df['Date'] = df['Date'].apply(lambda x: pd.to_datetime(x).strftime('%Y-%m-%d'))

# %%
df['Date'] = pd.to_datetime(df.Date)

# %%
filt = df.Mission_Status == "Failure"
df[filt].Mission_Status = "Awoe"
# Out:
# /tmp/ipykernel_81413/1667176177.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[filt].Mission_Status = "Awoe"

# %%
df[filt]
# Out:
#       Unnamed: 0.1  Unnamed: 0  Organisation  \
# 11              11          11        ExPace
# 15              15          15    Rocket Lab
# 27              27          27  Virgin Orbit
# 36              36          36          CASC
# 43              43          43          CASC
# ...            ...         ...           ...
# 4314          4314        4314       US Navy
# 4315          4315        4315     RVSN USSR
# 4318          4318        4318          AMBA
# 4319          4319        4319       US Navy
# 4321          4321        4321       US Navy
#
#                                                Location       Date  \
# 11      Site 95, Jiuquan Satellite Launch Center, China 2020-07-10
# 15      Rocket Lab LC-1A, M?hia Peninsula, New Zealand 2020-07-04
# 27    Cosmic Girl, Mojave Air and Space Port, Califo... 2020-05-25
# 36         LC-2, Xichang Satellite Launch Center, China 2020-04-09
# 43      LC-201, Wenchang Satellite Launch Center, China 2020-03-16
# ...
